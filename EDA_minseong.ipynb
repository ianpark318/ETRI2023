# %%
# !ls
# Out:
# EDA.ipynb	    README.md  eda.ipynb		  show_data.ipynb
# EDA_minseong.ipynb  data       feature_engineering.ipynb

# %%
import pandas as pd
import os

# %% [markdown]
# ## user_info

# %%
user_info = pd.read_csv('data/user_info_2020.csv')
# user_info = user_info.sort_values('userId')
user_info
# Out:
#     userId gender  age handed  height  weight     startDt       endDt
# 0   user24      F   26  Right     165      67  2020-08-29  2020-09-27
# 1   user23      M   35  Right     177      84  2020-08-31  2020-09-27
# 2   user05      M   31  Right     177      75  2020-08-31  2020-09-27
# 3   user04      M   28  Right     171      70  2020-08-31  2020-09-27
# 4   user12      F   30  Right     160      54  2020-08-30  2020-09-27
# 5   user08      M   32  Right     180      84  2020-08-31  2020-09-25
# 6   user02      F   25   Left     168      81  2020-08-31  2020-09-27
# 7   user10      M   25  Right     184      77  2020-08-30  2020-09-27
# 8   user03      F   32  Right     166      62  2020-08-29  2020-09-27
# 9   user11      M   32  Right     175      78  2020-08-30  2020-09-27
# 10  user28      M   31  Right     169      79  2020-08-31  2020-09-26
# 11  user21      F   26  Right     166      57  2020-08-29  2020-09-27
# 12  user26      F   27  Right     160      47  2020-08-31  2020-09-26
# 13  user01      M   27   Left     167      76  2020-08-30  2020-09-27
# 14  user22      F   30  Right     163      68  2020-09-01  2020-09-27
# 15  user29      M   29  Right     169      63  2020-08-30  2020-09-27
# 16  user25      M   27  Right     182      72  2020-08-31  2020-09-27
# 17  user09      M   20  Right     170      80  2020-08-31  2020-09-27
# 18  user30      M   26  Right     174      58  2020-08-31  2020-09-27
# 19  user07      M   30  Right     173      83  2020-08-31  2020-09-27
# 20  user27      F   28  Right     170      60  2020-09-04  2020-10-02
# 21  user06      F   22  Right     164      70  2020-09-11  2020-10-08

# %% [markdown]
# ## user_survey

# %%
user_survey = pd.read_csv('data/user_survey_2020.csv')
user_survey
# Out:
#       userId        date amPm        startInput          endInput  sleep  \
# 0     user24  2020-08-29   am  2020-08-29 21:23  2020-08-29 21:23    4.0
# 1     user24  2020-08-29   pm  2020-08-29 21:23  2020-08-29 21:23    NaN
# 2     user24  2020-08-30   am   2020-08-30 7:41   2020-08-30 7:41    3.0
# 3     user24  2020-08-30   pm  2020-08-30 22:43  2020-08-30 22:43    NaN
# 4     user24  2020-08-31   am   2020-08-31 7:23   2020-08-31 7:24    3.0
# ...      ...         ...  ...               ...               ...    ...
# 1225  user06  2020-10-06   pm   2020-10-07 0:07   2020-10-07 0:08    NaN
# 1226  user06  2020-10-07   am   2020-10-07 8:02   2020-10-07 8:05    2.0
# 1227  user06  2020-10-07   pm   2020-10-08 1:57   2020-10-08 1:57    NaN
# 1228  user06  2020-10-08   am   2020-10-08 8:23   2020-10-08 8:24    3.0
# 1229  user06  2020-10-08   pm  2020-10-08 23:30  2020-10-08 23:31    NaN
#
#       sleepProblem  dream  amCondition  amEmotion  pmEmotion  pmStress  \
# 0              0.0    3.0          3.0        4.0        NaN       NaN
# 1              NaN    NaN          NaN        NaN        4.0       4.0
# 2              2.0    2.0          2.0        3.0        NaN       NaN
# 3              NaN    NaN          NaN        NaN        4.0       5.0
# 4              2.0    2.0          3.0        3.0        NaN       NaN
# ...            ...    ...          ...        ...        ...       ...
# 1225           NaN    NaN          NaN        NaN        4.0       4.0
# 1226           9.0    4.0          2.0        3.0        NaN       NaN
# 1227           NaN    NaN          NaN        NaN        5.0       2.0
# 1228           0.0    4.0          2.0        2.0        NaN       NaN
# 1229           NaN    NaN          NaN        NaN        3.0       2.0
#
#       pmFatigue caffeine  cAmount(ml) alcohol  aAmount(ml)
# 0           NaN      NaN          NaN     NaN          NaN
# 1           2.0      NaN          NaN     NaN          NaN
# 2           NaN      NaN          NaN     NaN          NaN
# 3           2.0   coffee        200.0     NaN          NaN
# 4           NaN      NaN          NaN     NaN          NaN
# ...         ...      ...          ...     ...          ...
# 1225        4.0      NaN          NaN     NaN          NaN
# 1226        NaN      NaN          NaN     NaN          NaN
# 1227        3.0   coffee        250.0     NaN          NaN
# 1228        NaN      NaN          NaN     NaN          NaN
# 1229        2.0   coffee        300.0     NaN          NaN
#
# [1230 rows x 17 columns]

# %% [markdown]
# ## user_sleep

# %%
user_sleep = pd.read_csv('data/user_sleep_2020.csv')
user_sleep
# Out:
#      userId    timezone        date     startDt       endDt  lastUpdate  \
# 0    user24  Asia/Seoul  2020-08-30  1598708760  1598740860  1598748252
# 1    user24  Asia/Seoul  2020-08-31  1598800140  1598825940  1598833333
# 2    user24  Asia/Seoul  2020-09-01  1598885940  1598908800  1598916190
# 3    user24  Asia/Seoul  2020-09-02  1598979420  1598999580  1599006969
# 4    user24  Asia/Seoul  2020-09-03  1599060780  1599085980  1599093370
# ..      ...         ...         ...         ...         ...         ...
# 610  user06  Asia/Seoul  2020-10-05  1601831040  1601861820  1601862001
# 611  user06  Asia/Seoul  2020-10-06  1601923560  1601951220  1601951380
# 612  user06  Asia/Seoul  2020-10-07  1602001320  1602023760  1602031150
# 613  user06  Asia/Seoul  2020-10-08  1602091020  1602110280  1602117673
# 614  user06  Asia/Seoul  2020-10-09  1602183900  1602220140  1602227533
#
#      wakeupduration  lightsleepduration  deepsleepduration  wakeupcount  ...  \
# 0              3840               13800               9000            3  ...
# 1              4740                9540               6360            1  ...
# 2              1920                8760               4740            1  ...
# 3              2760                7740               7440            1  ...
# 4              3900               11640               7620            1  ...
# ..              ...                 ...                ...          ...  ...
# 610            8460               11820               4560            1  ...
# 611            1920               13200               7500            1  ...
# 612           12420                8520               1500            3  ...
# 613            4380                9240               4560            2  ...
# 614            3360               17820               7140            1  ...
#
#      hr_average  hr_min  hr_max  rr_average  rr_min  rr_max  \
# 0            72      63      82          15      10      20
# 1            69      60      82          15      11      20
# 2            70      58      94          15      12      23
# 3            68      60      80          15      12      19
# 4            71      61      83          15      11      25
# ..          ...     ...     ...         ...     ...     ...
# 610          48      43      81          17      12      22
# 611          52      47      84          17      10      23
# 612          47      42      76          16      12      20
# 613          52      47      68          17      10      20
# 614          52      45      69          17      10      23
#
#      breathing_disturbances_intensity  snoring  snoringepisodecount  \
# 0                                  10      840                    1
# 1                                   8     2700                    3
# 2                                   8        0                    0
# 3                                  -1      240                    1
# 4                                   7      300                    1
# ..                                ...      ...                  ...
# 610                                13     2400                    5
# 611                                10     1380                    4
# 612                                -1     1620                    4
# 613                                -1     2280                    2
# 614                                12     8340                    6
#
#      sleep_score
# 0             86
# 1             52
# 2             61
# 3             40
# 4             55
# ..           ...
# 610           60
# 611           79
# 612           20
# 613           20
# 614           87
#
# [615 rows x 23 columns]

# %%
'''
+----- USER_ID
 |        +----- timestamp (DAY 1)
 |         |        +----- e4Acc
 |         |         |        timestamp (e4_accelerometer_data).csv 
 |         |         |        ...
 |         |        +----- e4Bvp
 |         |         |        timestamp (e4_blood_volume_pressure_data).csv 
 |         |         |        ...
 |         |        +----- e4Eda
 |         |         |        timestamp (e4_electrodermal_activity_data).csv 
 |         |         |        ...
 |         |        +----- e4Hr
 |         |         |        timestamp (e4_heart_rate_data).csv 
 |         |         |        ...
 |         |        +----- e4Temp
 |         |         |        timestamp (e4_skin_temperature_data).csv 
 |         |         |        ...
 |         |        +----- mAcc
 |         |         |        timestamp (mobile_accelerometer_data).csv 
 |         |         |        ...
 |         |        +----- mGps
 |         |         |        timestamp (mobile_gps_data).csv 
 |         |         |        ...
 |         |        +----- mGyr
 |         |         |        timestamp (mobile_gyroscope_data).csv 
 |         |         |        ...
 |         |        +----- mMag
 |         |         |        timestamp (mobile_magnetometer_data).csv 
 |         |         |        ...
 |         |        timestamp_label.csv
 |        +----- timestamp (DAY 2)
 |         |        +----- ...
'''
# Out:
# '\n+----- USER_ID\n |        +----- timestamp (DAY 1)\n |         |        +----- e4Acc\n |         |         |        timestamp (e4_accelerometer_data).csv \n |         |         |        ...\n |         |        +----- e4Bvp\n |         |         |        timestamp (e4_blood_volume_pressure_data).csv \n |         |         |        ...\n |         |        +----- e4Eda\n |         |         |        timestamp (e4_electrodermal_activity_data).csv \n |         |         |        ...\n |         |        +----- e4Hr\n |         |         |        timestamp (e4_heart_rate_data).csv \n |         |         |        ...\n |         |        +----- e4Temp\n |         |         |        timestamp (e4_skin_temperature_data).csv \n |         |         |        ...\n |         |        +----- mAcc\n |         |         |        timestamp (mobile_accelerometer_data).csv \n |         |         |        ...\n |         |        +----- mGps\n |         |         |        timestamp (mobile_gps_data).csv \n |         |         |        ...\n |         |        +----- mGyr\n |         |         |        timestamp (mobile_gyroscope_data).csv \n |         |         |        ...\n |         |        +----- mMag\n |         |         |        timestamp (mobile_magnetometer_data).csv \n |         |         |        ...\n |         |        timestamp_label.csv\n |        +----- timestamp (DAY 2)\n |         |        +----- ...\n'

# %% [markdown]
# ## user_label

# %%
data_path = './data/dataset_2020/user06'

# %%
user_dir_list = os.listdir(data_path)

# print(dir_list)

user_label_list = []
for element in user_dir_list:
    label_data_path = data_path + '/' + element + '/' + element + '_label.csv'
    label_data = pd.read_csv(label_data_path)
    user_label_list.append(label_data)

# print(user_label_list)
df = pd.concat(user_label_list)
df['ts'] = pd.to_datetime(df['ts'], unit='s')
df = df.sort_values('ts')

df.head()
# df.tail()
# df
# Out:
#                    ts action  actionOption actionSub  actionSubOption  \
# 0 2020-09-10 17:00:00  sleep           111       NaN              NaN
# 1 2020-09-10 17:01:00  sleep           111       NaN              NaN
# 2 2020-09-10 17:02:00  sleep           111       NaN              NaN
# 3 2020-09-10 17:03:00  sleep           111       NaN              NaN
# 4 2020-09-10 17:04:00  sleep           111       NaN              NaN
#
#   condition  conditionSub1Option  conditionSub2Option place  emotionPositive  \
# 0  WITH_ONE                  1.0                  1.0  home                5
# 1  WITH_ONE                  1.0                  1.0  home                5
# 2  WITH_ONE                  1.0                  1.0  home                5
# 3  WITH_ONE                  1.0                  1.0  home                5
# 4  WITH_ONE                  1.0                  1.0  home                5
#
#    emotionTension  activity
# 0               1         3
# 1               1         3
# 2               1         3
# 3               1         3
# 4               1         3

# %%
df.columns
# Out:
# Index(['ts', 'action', 'actionOption', 'actionSub', 'actionSubOption',
#        'condition', 'conditionSub1Option', 'conditionSub2Option', 'place',
#        'emotionPositive', 'emotionTension', 'activity'],
#       dtype='object')

# %%
df.shape
# Out:
# (24390, 12)

# %%
from datetime import datetime

user_dir_list

for ele in user_dir_list:
    print(datetime.fromtimestamp(int(ele)).strftime("%Y-%m-%d, %H:%M:%S"))
# Out:
# 2020-10-02, 00:00:00
# 2020-10-08, 00:00:00
# 2020-09-28, 00:00:00
# 2020-09-13, 00:00:00
# 2020-09-26, 00:00:00
# 2020-10-03, 00:00:00
# 2020-10-07, 00:00:00
# 2020-10-06, 00:36:00
# 2020-09-17, 10:03:00
# 2020-09-23, 07:34:00
# 2020-09-20, 00:29:00
# 2020-09-12, 00:00:00
# 2020-09-16, 09:18:00
# 2020-10-01, 00:00:00
# 2020-10-04, 00:00:00
# 2020-09-21, 00:00:00
# 2020-09-24, 09:38:00
# 2020-09-22, 09:21:00
# 2020-09-19, 00:00:00
# 2020-09-15, 00:00:00
# 2020-09-27, 13:11:00
# 2020-10-05, 00:00:00
# 2020-09-18, 09:39:00
# 2020-09-11, 02:00:00
# 2020-09-14, 00:00:00
# 2020-09-30, 00:00:00
# 2020-09-25, 00:00:00
# 2020-09-29, 00:00:00

# %%
df
# Out:
#                       ts  action  actionOption    actionSub  actionSubOption  \
# 0    2020-09-10 17:00:00   sleep           111          NaN              NaN
# 1    2020-09-10 17:01:00   sleep           111          NaN              NaN
# 2    2020-09-10 17:02:00   sleep           111          NaN              NaN
# 3    2020-09-10 17:03:00   sleep           111          NaN              NaN
# 4    2020-09-10 17:04:00   sleep           111          NaN              NaN
# ...                  ...     ...           ...          ...              ...
# 1000 2020-10-08 13:16:00    meal           121  meal_amount              2.0
# 1001 2020-10-08 13:17:00    meal           121  meal_amount              2.0
# 1002 2020-10-08 13:18:00    meal           121  meal_amount              2.0
# 1003 2020-10-08 13:19:00    meal           121  meal_amount              2.0
# 1004 2020-10-08 14:29:00  travel            87  move_method              1.0
#
#       condition  conditionSub1Option  conditionSub2Option       place  \
# 0      WITH_ONE                  1.0                  1.0        home
# 1      WITH_ONE                  1.0                  1.0        home
# 2      WITH_ONE                  1.0                  1.0        home
# 3      WITH_ONE                  1.0                  1.0        home
# 4      WITH_ONE                  1.0                  1.0        home
# ...         ...                  ...                  ...         ...
# 1000  WITH_MANY                  4.0                  3.0  restaurant
# 1001  WITH_MANY                  4.0                  3.0  restaurant
# 1002  WITH_MANY                  4.0                  3.0  restaurant
# 1003  WITH_MANY                  4.0                  3.0  restaurant
# 1004   WITH_ONE                  4.0                  3.0     outdoor
#
#       emotionPositive  emotionTension  activity
# 0                   5               1         3
# 1                   5               1         3
# 2                   5               1         3
# 3                   5               1         3
# 4                   5               1         3
# ...               ...             ...       ...
# 1000                5               2         3
# 1001                5               2         3
# 1002                5               2         3
# 1003                5               2         3
# 1004                3               2         3
#
# [24390 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24390 entries, 0 to 1004
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ts                   24390 non-null  datetime64[ns]
#  1   action               24390 non-null  object
#  2   actionOption         24390 non-null  int64
#  3   actionSub            3126 non-null   object
#  4   actionSubOption      3126 non-null   float64
#  5   condition            24390 non-null  object
#  6   conditionSub1Option  14624 non-null  float64
#  7   conditionSub2Option  14624 non-null  float64
#  8   place                24390 non-null  object
#  9   emotionPositive      24390 non-null  int64
#  10  emotionTension       24390 non-null  int64
#  11  activity             24390 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(4)
# memory usage: 2.4+ MB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

le.fit(df['action'])
le.transform(df['action'])
df['action'] = le.transform(df['action'])

# %%
attrs = ['action', 'actionSub', 'condition', 'place']
attrs_float = ['actionSubOption', 'conditionSub1Option', 'conditionSub2Option']


for attr in attrs:
    le = LabelEncoder()
    
    le.fit(df[attr])
    le.transform(df[attr])
    df[attr] = le.transform(df[attr])

# %%
df.dropna(axis=0)
# Out:
#                       ts  action  actionOption  actionSub  actionSubOption  \
# 350  2020-09-12 03:55:00       2           121          0              3.0
# 351  2020-09-12 03:56:00       2           121          0              3.0
# 352  2020-09-12 03:57:00       2           121          0              3.0
# 353  2020-09-12 03:58:00       2           121          0              3.0
# 354  2020-09-12 03:59:00       2           121          0              3.0
# ...                  ...     ...           ...        ...              ...
# 1000 2020-10-08 13:16:00       2           121          0              2.0
# 1001 2020-10-08 13:17:00       2           121          0              2.0
# 1002 2020-10-08 13:18:00       2           121          0              2.0
# 1003 2020-10-08 13:19:00       2           121          0              2.0
# 1004 2020-10-08 14:29:00      10            87          1              1.0
#
#       condition  conditionSub1Option  conditionSub2Option  place  \
# 350           2                  1.0                  2.0      0
# 351           2                  1.0                  2.0      0
# 352           2                  1.0                  2.0      0
# 353           2                  1.0                  2.0      0
# 354           2                  1.0                  2.0      0
# ...         ...                  ...                  ...    ...
# 1000          1                  4.0                  3.0      3
# 1001          1                  4.0                  3.0      3
# 1002          1                  4.0                  3.0      3
# 1003          1                  4.0                  3.0      3
# 1004          2                  4.0                  3.0      2
#
#       emotionPositive  emotionTension  activity
# 350                 6               1         3
# 351                 6               1         3
# 352                 6               1         3
# 353                 6               1         3
# 354                 6               1         3
# ...               ...             ...       ...
# 1000                5               2         3
# 1001                5               2         3
# 1002                5               2         3
# 1003                5               2         3
# 1004                3               2         3
#
# [1477 rows x 12 columns]

# %% [markdown]
# ## Sensor

# %%
user_dir_list = os.listdir(data_path)
user_dir_list.sort()

user_label_list = []
# sensors = ['e4Acc', 'e4Bvp', 'e4Eda', 'e4Hr', 'e4Temp', 'mAcc', 'mGps', 'mGyr', 'mMag']


Acc_data_list = []
# print(user_dir_list)

acc_path = data_path + '/' + user_dir_list[0] + '/' + 'e4Acc'

acc_csv_list = os.listdir(acc_path)
acc_csv_list.sort()

# print(acc_csv_list)

df_e4Acc_fir = []
for i in range(len(acc_csv_list)):
    df_acc_fir = pd.read_csv(acc_path + '/' + acc_csv_list[i])
    df_e4Acc_fir.append(df_acc_fir)
    


df_e4Acc_fir[0]
# Out:
#       timestamp         x         y         z
# 0        13.000 -0.171875 -0.718750  0.515625
# 1        13.031 -0.109375 -0.734375  0.515625
# 2        13.062 -0.031250 -0.734375  0.515625
# 3        13.093  0.031250 -0.765625  0.468750
# 4        13.125  0.046875 -0.796875  0.437500
# ...         ...       ...       ...       ...
# 1499     59.843 -0.265625  0.953125 -0.140625
# 1500     59.875 -0.296875  0.968750 -0.156250
# 1501     59.906 -0.343750  0.968750 -0.187500
# 1502     59.937 -0.328125  1.000000 -0.171875
# 1503     59.968 -0.296875  1.000000 -0.187500
#
# [1504 rows x 4 columns]

# %%
print(f'cnt: {df_acc_fir.count()}')
print()
print(f'min: {df_acc_fir.min()}\n')
print(f'25%: {df_acc_fir.quantile(.25)}\n')
print(f'50%: {df_acc_fir.quantile(.50)}\n')
print(f'75%: {df_acc_fir.quantile(.75)}\n')
print(f'max: {df_acc_fir.max()}\n')
print()

print(f'mean: {df_acc_fir.mean()}\n')
print(f'median: {df_acc_fir.median()}\n')
# print(f'mode: {df_acc_fir.mode()}\n')

# print(df_acc_fir.median()['x'])

instruction_list = ['df_acc_fir.min()', 'df_acc_fir.quantile(.25)', 'df_acc_fir.quantile(.50)',
                    'df_acc_fir.quantile(.75)', 'df_acc_fir.max()', 'df_acc_fir.mean()', 'df_acc_fir.median()']
acc_info = {}

for instruction in instruction_list:
    x,y,z = eval(instruction+'[\'x\']'), eval(instruction+'[\'y\']'), eval(instruction+'[\'z\']')
    
    acc_info[instruction[11:]] = [x,y,z]

    
print(acc_info)
# Out:
# cnt: timestamp    1254
# x            1254
# y            1254
# z            1254
# dtype: int64
#
# min: timestamp    0.000000
# x           -1.796875
# y           -1.140625
# z           -1.125000
# dtype: float64
#
# 25%: timestamp    9.788750
# x           -0.890625
# y           -0.562500
# z            0.046875
# Name: 0.25, dtype: float64
#
# 50%: timestamp    19.577500
# x            -0.765625
# y            -0.281250
# z             0.257812
# Name: 0.5, dtype: float64
#
# 75%: timestamp    29.367000
# x            -0.562500
# y             0.156250
# z             0.546875
# Name: 0.75, dtype: float64
#
# max: timestamp    39.156000
# x             1.046875
# y             1.718750
# z             1.390625
# dtype: float64
#
#
# mean: timestamp    19.577750
# x            -0.653372
# y            -0.186092
# z             0.253738
# dtype: float64
#
# median: timestamp    19.577500
# x            -0.765625
# y            -0.281250
# z             0.257812
# dtype: float64
#
# {'min()': [-1.796875, -1.140625, -1.125], 'quantile(.25)': [-0.890625, -0.5625, 0.046875], 'quantile(.50)': [-0.765625, -0.28125, 0.2578125], 'quantile(.75)': [-0.5625, 0.15625, 0.546875], 'max()': [1.046875, 1.71875, 1.390625], 'mean()': [-0.6533717105263158, -0.18609200558213715, 0.25373803827751196], 'median()': [-0.765625, -0.28125, 0.2578125]}

# %% [markdown]
# ## plot 그리기

# %%
len(df_e4Acc_fir)
# Out:
# 740

# %%
from scipy.interpolate import splrep, splev
import seaborn as sns


def plot_Acc_ftt(df, i):
    
    fs = 1000
    dt = 1/fs
    
    fig = plt.figure(figsize=(15,5))
    X, Y, Z = df_e4Acc_fir[i]['x'], df_e4Acc_fir[i]['y'], df_e4Acc_fir[i]['z']
    
    #     print(X)
    #     print(type(X))

    #     print(list(X))

    plt.subplot(3, 1, 1)
    plt.plot(df[i]['timestamp'], list(X))

    plt.subplot(3, 1, 2)
    plt.plot(df[i]['timestamp'],  list(Y))

    plt.subplot(3, 1, 3)
    plt.plot(df[i]['timestamp'],  list(Z))

    plt.show()

# %%
plot_Acc_ftt(df_e4Acc_fir, 245)

# %%
from scipy.interpolate import splrep, splev
import seaborn as sns
from mpl_toolkits.mplot3d import axes3d


def plot_Acc_ftt(df, i):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    fs = 1000
    dt = 1/fs
    
    spl_x = splrep(df[i]["timestamp"], df[i]["x"])
    spl_y = splrep(df[i]["timestamp"], df[i]["y"])
    spl_z = splrep(df[i]["timestamp"], df[i]["z"])
    
    
    fig = plt.figure(figsize=(15,5))
    X, Y, Z = splev(df_e4Acc_fir[i]['x'], spl_x), splev(df_e4Acc_fir[i]['y'],spl_y), splev(df_e4Acc_fir[i]['z'], spl_z)
    
#     print(X)
    #     print(type(X))

#     print(list(X))
#     print(df_e4Acc_fir[i]['z'])

    plt.subplot(3, 1, 1)
    plt.plot(df[i]['timestamp'], list(X))

    plt.subplot(3, 1, 2)
    plt.plot(df[i]['timestamp'],  list(Y))

    plt.subplot(3, 1, 3)
    plt.plot(df[i]['timestamp'],  list(Z))
    

    plt.tight_layout()
    plt.show()

# %%
plot_Acc_ftt(df_e4Acc_fir, 245)

# %%
from scipy.interpolate import splrep, splev
import seaborn as sns
from mpl_toolkits.mplot3d import axes3d


def plot_Acc_ftt_3d(df, i):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    fs = 1000
    dt = 1/fs
    
    spl_x = splrep(df[i]["timestamp"], df[i]["x"])
    spl_y = splrep(df[i]["timestamp"], df[i]["y"])
    spl_z = splrep(df[i]["timestamp"], df[i]["z"])
    
    
    fig = plt.figure(figsize=(15,5))
    X, Y, Z = splev(df_e4Acc_fir[i]['x'], spl_x), splev(df_e4Acc_fir[i]['y'],spl_y), splev(df_e4Acc_fir[i]['z'], spl_z)

    # for 3d plot
    ax = fig.gca(projection='3d')

    ax.scatter(X, Y, Z)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')


    plt.tight_layout()
    plt.show()

# %%
plot_Acc_ftt_3d(df_e4Acc_fir, 245)
# Out:
# /tmp/ipykernel_115059/755756099.py:21: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
plot_Acc_ftt_3d(df_e4Acc_fir, 33)
# Out:
# /tmp/ipykernel_115059/755756099.py:21: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
plot_Acc_ftt_3d(df_e4Acc_fir, 100)
# Out:
# /tmp/ipykernel_115059/755756099.py:21: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
plot_Acc_ftt_3d(df_e4Acc_fir, 199)
# Out:
# /tmp/ipykernel_115059/755756099.py:21: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
